# %% [markdown]
# # Data analysis for Launchpad

# %% [markdown]
# Pandas documentation and tutorials:
# http://playittodeath.ru/%D0%B0%D0%BD%D0%B0%D0%BB%D0%B8%D0%B7-%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85-%D0%BF%D1%80%D0%B8-%D0%BF%D0%BE%D0%BC%D0%BE%D1%89%D0%B8-python-%D0%B3%D1%80%D0%B0%D1%84%D0%B8%D0%BA%D0%B8-%D0%B2-pandas/
# http://habrahabr.ru/post/202090/
# http://www.youtube.com/watch?v=e3oJ3I-i6Yg

# %% [markdown]
# ## Graphs playground

# %%
x = np.linspace(0, 2*np.pi, 200)

# %%
# %matplotlib inline
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('title')
#axes.plot(x, np.sin(x), 'r')
#axes.plot(x, np.cos(x), 'g')
axes.plot(x, np.sin(x)**2, 'b')
axes.plot(x, np.cos(x)**2, 'y')
axes.plot(x, np.abs(np.sin(x)), 'g')
axes.plot(x, np.abs(np.cos(x)), 'p')
axes.plot(x, np.sin(x)**2 + np.cos(x)**2, 'r')

# %%
fig = plt.figure(figsize=(20,20))
ax = fig.add_axes([0.0, 0.0, .6, .6], polar=True)
for i in range(0, 9):
    n = 2**i
    size = np.pi / (i / 2 + 1) ** 2
    size = np.pi / n
    shift = size / 2
    t1 = np.linspace(i + 2, i+2, 5)
    for j in range (0, n):
        t = np.linspace(0 + shift+size*2*j, size*(2*j+1) + shift, 5)
        ax.plot(t, t1, color='blue', lw=3);
t1 = np.linspace(1, 1, 5)
t = np.linspace(0, np.pi, 5)
ax.plot(t, t1, color='blue', lw=3);
# fig.savefig('graph.png')

# %% [markdown]
# ## Pandas playground

# %%
import pandas as pd
import numpy as p

# %%
df1 = pd.DataFrame({'Ivan': ['M', 25], 'Peter': ['M', 30], 'Oleg': ['M', 28], 'Olga': ['W', 32]}, index=['sex', 'age']).transpose()
df2 = pd.DataFrame({'Volvo': ['Peter', 2], 'Audi': ['Peter', 1], 'Nissan': ['Olga', 4]}, index=['owner', 'age']).transpose()
df2
# Out:
#         owner age
# Audi    Peter   1
# Nissan   Olga   4
# Volvo   Peter   2

# %%
# df.to_csv('open_fuel_8_0.csv', encoding='utf-8')
df = pd.DataFrame.from_csv('open_fuel_8_0.csv')
df
# Out:
#                                                      title  heat  \
# 1252730  [nailgun] Need to present notification for use...     6
# 1255426  Progress shows 100% for deploy while there is ...    12
# 1260268  [iso] Customize Cirros image for include follo...     6
# 1262313  Virtual Storage LVM volume is not needed when ...    14
# 1263046  [nailgun] Wrong compute node status via deploy...     6
# 1263202  [nailgun] Allow user to specify possible resiz...     6
# 1263895  [nailgun] Nailgun dont handle cases when deplo...    12
# 1264494  [library] add vlan tag option to fuelmenu for ...     6
# 1268278  [nailgun] Provide more debugging info for nail...     6
# 1271070  [ui] There is no validation of IP ranges inter...    18
# 1273006   [nailgun] nodes don't return to discovered state    14
# 1279371  [nailgun] Split diagnostic snapshot into manag...     8
# 1283222            [devops] refactor fuel-web jenkins jobs     6
# 1284120  [library] remote rsyslog should create deleted...     8
# 1286110  Min level filter changes from ERROR to INFO fo...     6
# 1286151  [OSTF] OSTF processes should be killed when re...     6
# 1286203  [nailgun] Roles assignment validation doesn't ...     6
# 1292486  [devops] Create Jenkins job to run selenium ui...   158
# 1293028  [devops] Configure test coverage reports for N...     6
# 1295717  [provision] Controller has unallocated space, ...     6
# 1303762  [puppet] Fuel Library has dynamic lookup in te...     6
# 1306792  [volumes-refactoring] Fuel Default Disk Partio...    10
# 1307495  [devops] Recheck no bug doesn't retrigger Fuel CI    14
# 1310646  [library] unit-tests for l23network new resour...     8
# 1312238      [provision] Kill installer on critical errors     6
# 1321473  [devops] create CI test around deployment-runt...    10
# 1322073  [nailgun] Need to redefine network ext_net_dat...     6
# 1322114  [devops] Document and train US team for system...     8
# 1323555                        Storage settings in Fuel UI     6
# 1323600  [devops] Measure system test thread loads for ...     6
# ...                                                    ...   ...
# 1506008  Cannot delete 'controller+ceph' node and stran...     6
# 1506040            Log debug option for deadlocks detector     6
# 1506041  [fuel-octane]Need to remove upgrade_levels fro...     6
# 1506071  fuel-agent should retry if loop device allocat...     6
# 1506073        tenant is missing for most keystone-* tasks     6
# 1506112  Scale deployment has failed on 200 nodes with ...     6
# 1506131  Name 'Level' in Japanese incorrectly displays ...     6
# 1506377  [system-tests] Logging in upgrade method does ...     6
# 1506398  octane upgrade-control breaks mysql and rabbit...     6
# 1506401  octane upgrade-control doesn't include check f...     6
# 1506405  when octane upgrade-node fail with compute nod...     6
# 1506407  octane install-node often fails on provision step     6
# 1506423           ShellCheck issues in rabbitmq OCF script     6
# 1506440  Fix RabbitMQ OCF script rely on the exit code ...     6
# 1506449  Timeout of deployment is exceeded after deleti...     6
# 1506506                   Make OSTF results more readable      6
# 1506522  fpb should not add requires for perl files in ...     6
# 1506542     exit_with_error must be replaced by exceptions     6
# 1506557  Turn on rspec test coverage reporting for fuel...     6
# 1506624          Example v3 plugin fail cluster deployment     6
# 1506755  [system-tests] Upgrade tests failed due to inc...     6
# 1506765  fuel-agent: sync versions in requrements.txt w...     6
# 1506810  Cannot find running container with name "fuel-...     6
# 1506820   Support of IP ranges for all networks by default     6
# 1506828              Cluster name shifted on Dashboard tab     6
# 1506870  'resume_guest_state_on_host_boot=True' by default     6
# 1506885     Move fuelmenu to a separate repo from fuel-web     6
# 1506894  Move shotgun to a separate repository from fue...     6
# 1506896  Move network checker to a separate repo from f...     6
# 1506915  Nailgun can't provide default deployment setti...     6
#
#          message_count                                               tags  \
# 1252730              2         [feature, module-master-node-installation]
# 1255426              7  [covered-by-bp, feature-progress-bar, module-a...
# 1260268              4                                                 []
# 1262313              8  [ceph, feature, known-issue, module-volumes, q...
# 1263046              7                             [module-tasks, size-l]
# 1263202              4                       [feature, low-hanging-fruit]
# 1263895             11                             [feature, known-issue]
# 1264494              3                         [feature, module-fuelmenu]
# 1268278              2                                [size-s, tech-debt]
# 1271070              6                                               [ui]
# 1273006             12                             [feature, known-issue]
# 1279371              3          [customer-found, feature, module-shotgun]
# 1283222              3     [devops, jenkins, module-nailgun, non-release]
# 1284120              5         [customer-found, feature, feature-logging]
# 1286110              6                                       [astute, ui]
# 1286151              6  [feature, feature-reset-env, feature-stop-depl...
# 1286203              7  [feature, feature-validation, known-issue, low...
# 1292486             10                     [devops, jenkins, non-release]
# 1293028              4   [devops, module-nailgun, non-release, tech-debt]
# 1295717             17  [ceph, module-volumes, qa-agree-7.0, release-n...
# 1303762              3                                                 []
# 1306792             11  [blocked-by-bp, covered-by-bp, customer-found,...
# 1307495              3                             [fuel-ci, non-release]
# 1310646             11               [l23network, non-release, tech-debt]
# 1312238              1                                      [non-release]
# 1321473              3                [devops, non-release, system-tests]
# 1322073              1                                [size-s, tech-debt]
# 1322114              2              [devops, docs, non-release, techtalk]
# 1323555              9                               [docs, qa-agree-7.0]
# 1323600              1                              [devops, non-release]
# ...                ...                                                ...
# 1506008              5                                             [ceph]
# 1506040              2                                        [tech-debt]
# 1506041              1                                    [module-octane]
# 1506071              1                           [ibp, low-hanging-fruit]
# 1506073              1                                        [tech-debt]
# 1506112              6                                                 []
# 1506131              2                                               [ui]
# 1506377              2                                     [system-tests]
# 1506398              1                                    [module-octane]
# 1506401              1                                    [module-octane]
# 1506405              2                                    [module-octane]
# 1506407              3                                    [module-octane]
# 1506423              1                                         [rabbitmq]
# 1506440              2                                                 []
# 1506449              1                            [life-cycle-management]
# 1506506              5                  [low-hanging-fruit, system-tests]
# 1506522              2                                                 []
# 1506542              1      [low-hanging-fruit, module-client, tech-debt]
# 1506557              2                                                 []
# 1506624              4                     [module-astute, swarm-blocker]
# 1506755              3                      [swarm-blocker, system-tests]
# 1506765              3                                                 []
# 1506810              2                                    [swarm-blocker]
# 1506820              1  [feature, feature-advanced-networking, module-...
# 1506828              3                                               [ui]
# 1506870              1                                                 []
# 1506885              1                                                 []
# 1506894              1                                                 []
# 1506896              3                                                 []
# 1506915              2                                   [module-nailgun]
#
#         private security_related  users_affected_count  number_of_duplicates  \
# 1252730   False            False                     1                     0
# 1255426   False            False                     2                     0
# 1260268   False            False                     1                     0
# 1262313   False            False                     3                     0
# 1263046   False            False                     1                     0
# 1263202   False            False                     1                     0
# 1263895   False            False                     2                     0
# 1264494   False            False                     1                     0
# 1268278   False            False                     1                     0
# 1271070   False            False                     2                     1
# 1273006   False            False                     3                     0
# 1279371   False            False                     1                     0
# 1283222   False            False                     1                     0
# 1284120   False            False                     1                     0
# 1286110   False            False                     1                     0
# 1286151   False            False                     1                     0
# 1286203   False            False                     1                     0
# 1292486    True            False                     1                     0
# 1293028   False            False                     1                     0
# 1295717   False            False                     1                     0
# 1303762   False            False                     1                     0
# 1306792   False            False                     2                     0
# 1307495   False            False                     3                     0
# 1310646   False            False                     1                     0
# 1312238   False            False                     1                     0
# 1321473   False            False                     2                     0
# 1322073   False            False                     1                     0
# 1322114   False            False                     1                     0
# 1323555   False            False                     1                     0
# 1323600   False            False                     1                     0
# ...         ...              ...                   ...                   ...
# 1506008   False            False                     1                     0
# 1506040   False            False                     1                     0
# 1506041   False            False                     1                     0
# 1506071   False            False                     1                     0
# 1506073   False            False                     1                     0
# 1506112   False            False                     1                     0
# 1506624                  NaN                 NaN              NaN
# 1506755                  NaN                 NaN              NaN
# 1506765                  NaN                 NaN              NaN
# 1506810                  NaN                 NaN              NaN
# 1506820                  NaN                 NaN              NaN
# 1506828                  NaN                 NaN              NaN
# 1506870                  NaN                 NaN              NaN
# 1506885                  NaN                 NaN              NaN
# 1506894                  NaN                 NaN              NaN
# 1506896                  NaN                 NaN              NaN
# 1506915                  NaN                 NaN              NaN
#
#          7.0-mu-1_is_complete  7.0-mu-1_assignee  8.0_importance   8.0_status  \
# 1252730                   NaN                NaN            High      Triaged
# 1255426                   NaN                NaN             Low    Confirmed
# 1260268                   NaN                NaN        Wishlist    Confirmed
# 1262313                   NaN                NaN            High      Triaged
# 1263046                   NaN                NaN        Wishlist    Confirmed
# 1263202                   NaN                NaN             Low      Triaged
# 1263895                   NaN                NaN            High      Triaged
# 1264494                   NaN                NaN          Medium      Triaged
# 1268278                   NaN                NaN        Wishlist    Confirmed
# 1271070                   NaN                NaN             Low    Confirmed
# 1273006                   NaN                NaN          Medium      Triaged
# 1279371                   NaN                NaN        Wishlist    Confirmed
# 1283222                   NaN                NaN          Medium    Confirmed
# 1284120                   NaN                NaN          Medium      Triaged
# 1286110                   NaN                NaN             Low    Confirmed
# 1286151                   NaN                NaN            High      Triaged
# 1286203                   NaN                NaN          Medium      Triaged
# 1292486                   NaN                NaN          Medium    Confirmed
# 1293028                   NaN                NaN             Low    Confirmed
# 1295717                   NaN                NaN          Medium    Confirmed
# 1303762                   NaN                NaN             Low    Confirmed
# 1306792                   NaN                NaN            High    Confirmed
# 1307495                   NaN                NaN          Medium    Confirmed
# 1310646                   NaN                NaN          Medium  In Progress
# 1312238                   NaN                NaN             Low    Confirmed
# 1321473                   NaN                NaN          Medium    Confirmed
# 1322073                   NaN                NaN        Wishlist    Confirmed
# 1322114                   NaN                NaN          Medium    Confirmed
# 1323555                   NaN                NaN          Medium    Confirmed
# 1323600                   NaN                NaN        Wishlist    Confirmed
# ...                       ...                ...             ...          ...
# 1506008                   NaN                NaN            High    Confirmed
# 1506040                   NaN                NaN          Medium  In Progress
# 1506041                   NaN                NaN            High    Confirmed
# 1506071                   NaN                NaN          Medium      Triaged
# 1506073                   NaN                NaN          Medium      Triaged
# 1506112                   NaN                NaN            High    Confirmed
# 1506131                   NaN                NaN             Low    Confirmed
# 1506377                   NaN                NaN          Medium  In Progress
# 1506398                   NaN                NaN            High    Confirmed
# 1506401                   NaN                NaN          Medium    Confirmed
# 1506405                   NaN                NaN        Critical    Confirmed
# 1506407                   NaN                NaN            High    Confirmed
# 1506423                   NaN                NaN          Medium    Confirmed
# 1506440                   NaN                NaN            High  In Progress
# 1506449                   NaN                NaN            High    Confirmed
# 1506506                   NaN                NaN             Low  In Progress
# 1506522                   NaN                NaN          Medium  In Progress
# 1506542                   NaN                NaN          Medium    Confirmed
# 1506557                   NaN                NaN          Medium  In Progress
# 1506624                   NaN                NaN            High  In Progress
# 1506755                   NaN                NaN            High  In Progress
# 1506765                   NaN                NaN            High  In Progress
# 1506810                   NaN                NaN            High    Confirmed
# 1506820                   NaN                NaN            High      Triaged
# 1506828                   NaN                NaN          Medium  In Progress
# 1506870                   NaN                NaN            High    Confirmed
# 1506885                   NaN                NaN          Medium      Triaged
# 1506894                   NaN                NaN          Medium      Triaged
# 1506896                   NaN                NaN          Medium  In Progress
# 1506915                   NaN                NaN          Medium    Confirmed
#
#         8.0_is_complete   8.0_assignee
# 1252730           False    fuel-python
# 1255426           False    fuel-python
# 1260268           False      mos-linux
# 1262313           False    fuel-python
# 1263046           False    fuel-python
# 1263202           False    fuel-python
# 1263895           False    fuel-python
# 1264494           False   fuel-library
# 1268278           False    fuel-python
# 1271070           False        fuel-ui
# 1273006           False    fuel-python
# 1279371           False    fuel-python
# 1283222           False        fuel-ci
# 1284120           False    fuel-python
# 1286110           False   fuel-library
# 1286151           False    fuel-python
# 1286203           False      vsharshov
# 1292486           False  mmatuszkowiak
# 1293028           False    fuel-devops
# 1295717           False    fuel-python
# 1303762           False   fuel-library
# 1306792           False    fuel-python
# 1307495           False        fuel-ci
# 1310646           False        xenolog
# 1312238           False     fuel-build
# 1321473           False         xarses
# 1322073           False    alekseyk-ru
# 1322114           False    fuel-devops
# 1323555           False        fuel-ui
# 1323600           False        fuel-ci
# ...                 ...            ...
# 1506008           False    fuel-python
# 1506040           False     akislitsky
# 1506041           False    fuel-octane
# 1506071           False    fuel-python
# 1506073           False      raytrac3r
# 1506112           False    fuel-python
# 1506131           False        fuel-ui
# 1506377           False      vkhlyunev
# 1506398           False    fuel-octane
# 1506401           False    fuel-octane
# 1506405           False    fuel-octane
# 1506407           False    fuel-octane
# 1506423           False       mos-oslo
# 1506440           False       bogdando
# 1506449           False   fuel-library
# 1506506           False         vgorin
# 1506522           False      raytrac3r
# 1506542           False      atykhonov
# 1506557           False   alex-schultz
# 1506624           False     ikalnitsky
# 1506755           False      ddmitriev
# 1506765           False       vsaienko
# 1506810           False    fuel-python
# 1506820           False      ivankliuk
# 1506828           False    astepanchuk
# 1506870           False   fuel-library
# 1506885           False     kozhukalov
# 1506894           False     kozhukalov
# 1506896           False     kozhukalov
# 1506915           False    fuel-python
#
# [914 rows x 82 columns]

# %%
import yaml
with open("teams.yml", 'r') as stream:
    teams_map = yaml.load(stream)

teams_map
# Out:
# {'fuel-build': [u'r0mikiam',
#   u'sotpuschennikov',
#   u'mrasskazov',
#   u'vparakhin',
#   u'dburmistrov',
#   u'skulanov',
#   u'kozhukalov'],
#  'fuel-ci': [u'akaszuba',
#   u'aevseev-h',
#   u'dkaiharodsev',
#   u'ibelikov',
#   u'afedorova'],
#  'fuel-devops': [u'heos',
#   u'teran',
#   u'pbrzozowski',
#   u'mmatuszkowiak',
#   u'skulanov',
#   u'acharykov'],
#  'fuel-docs': [u'evkonstantinov',
#   u'aadamov',
#   u'mzlatkova',
#   u'ologvinova',
#   u'ogusarenko',
#   u'skarslioglu',
#   u'tzn',
#   u'fsoppelsa',
#   u'dborodaenko',
#   u'ipovolotskaya',
#   u'eshumakher'],
#  'fuel-library': [u'mmalchuk',
#   u'kgalanov',
#   u'zynzel',
#   u'ashtokolov',
#   u'alex-schultz',
#   u'sbogatkin',
#   u'bpiotrowski',
#   u'tzn',
#   u'smakar',
#   u'omolchanov',
#   u'sgolovatiuk',
#   u'adidenko',
#   u'bogdando',
#   u'raytrac3r',
#   u'xenolog',
#   u'dborodaenko',
#   u'xarses',
#   u'idv1985',
#   u'vkuklin'],
#  u'fuel-maintainers': [u'afedorova'],
#  u'fuel-octane': [u'sryabin',
#   u'smurashov',
#   u'yorik-sar',
#   u'akscram',
#   u'gelbuhos'],
#  u'fuel-partner-core': [u'ipolliul',
#   u'jjainschigg-r',
#   u'omandryka',
#   u'popovych-andrey',
#   u'aarzhanov',
#   u'otsvigun',
#   u'ibumarskov',
#   u'rkhozinov',
#   u'omartsyniuk',
#   u'anoga',
#   u'igajsin',
#   u'gcon-monolake',
#   u'ekorekin',
#   u'okosse',
#   u'azemlyanov',
#   u'izinovik',
#   u'srogov',
#   u'eshumakher'],
#  'fuel-partner-engineering': [u'anoga',
#   u'fuel-partner-eng-qa',
#   u'fuel-partner-eng-dev'],
#  'fuel-plugin-calico': [u'neil-jerram', u'emma-0'],
#  'fuel-plugin-cinder-netapp': [u'samuel-bartel', u'dukov', u'prmtl'],
#  'fuel-plugin-cisco-aci': [u'bose', u'dhami', u'slevchenko'],
#  'fuel-plugin-contrail': [u'ipolliul', u'ivovk', u'anoga', u'omartsyniuk'],
#  'fuel-plugin-external-glusterfs': [u'sbogatkin', u'prmtl'],
#  'fuel-plugin-vmware-dvs': [u'vtabolin', u'igajsin', u'otsvigun'],
#  'fuel-plugin-zabbix': [u'simon-pasquier',
#   u'swann-w',
#   u'patrick-michel-petit',
#   u'rlu',
#   u'zynzel',
#   u'zatserklyany'],
#  'fuel-plugins-bugs': [u'rlu',
#   u'srogov',
#   u'carmela-rubinos',
#   u'aurlapova',
#   u'guillaume-thouvenin',
#   u'devvesa',
#   u'aignatov',
#   u'skolekonov',
#   u'rkhozinov',
#   u'ibumarskov',
#   u'sbogatkin',
#   u'ivovk',
#   u'igajsin',
#   u'otsvigun',
#   u'sbanka',
#   u'aepifanov',
#   u'emma-0',
#   u'omartsyniuk',
#   u'simon-pasquier',
#   u'omandryka',
#   u'ipovolotskaya'],
#  'fuel-plugins-docs': [u'ipovolotskaya'],
#  'fuel-python': [u'bgaifullin',
#   u'atykhonov',
#   u'xmig',
#   u'sergey.vilgelm',
#   u'lefremova',
#   u'abochkarev',
#   u'ipukha',
#   u'slava-val-al',
#   u'asvechnikov',
#   u'fzhadaev',
#   u'pkaminski',
#   u'ekosareva',
#   u'cutwater',
#   u'romcheg',
#   u'rmoe',
#   u'thomas-goirand',
#   u'dpyzhov',
#   u'vsharshov',
#   u'sbrzeczkowski',
#   u'maciej-iai',
#   u'popovych-andrey',
#   u'loles',
#   u'a-gordeev',
#   u'akislitsky',
#   u'okosse',
#   u'ivankliuk',
#   u'chenh1987',
#   u'kozhukalov',
#   u'prmtl',
#   u'aroma-x',
#   u'dshulyak',
#   u'ksambor',
#   u'ikalnitsky',
#   u'rustyrobot',
#   u'alekseyk-ru'],
#  'fuel-qa': [u'akostrikov-mirantis',
#   u'vkhlyunev',
#   u'kdemina',
#   u'aarzhanov',
#   u'akurenyshev',
#   u'ishamrai',
#   u'agrechanichenko',
#   u'vgorin',
#   u'unbelll',
#   u'mykhaylo-slobodyan',
#   u'dtyzhnenko',
#   u'tdubyk',
#   u'komelchenko',
#   u'ddmitriev',
#   u'apanchenko-8',
#   u'asledzinskiy',
#   u'ykotko',
#   u'anaboikina',
#   u'apalkina',
#   u'teran',
#   u'tatyana-leontovich',
#   u'aurlapova'],
#  'fuel-security': [u'acharykov',
#   u'dpyzhov',
#   u'mirantisbot',
#   u'bpiotrowski',
#   u'apanchenko-8',
#   u'zynzel',
#   u'aheczko-mirantis',
#   u'ebogdanov',
#   u'maximov',
#   u'sgolovatiuk',
#   u'bogdando',
#   u'adidenko',
#   u'vsharshov',
#   u'idv1985',
#   u'raytrac3r',
#   u'omolchanov',
#   u'smakar',
#   u'sbogatkin',
#   u'imarnat',
#   u'kozhukalov',
#   u'ielterman',
#   u'amogylchenko',
#   u'asheplyakov',
#   u'tzn',
#   u'dmitrymex',
#   u'msemenov',
#   u'fuel-drivers',
#   u'afedorova'],
#  'fuel-ui': [u'kpimenova',
#   u'vkramskikh',
#   u'bdudko',
#   u'astepanchuk',
#   u'jkirnosova'],
#  'mos-ceilometer': [u'ityaptin',
#   u'iberezovskiy',
#   u'idegtiarov',
#   u'nprivalova'],
#  'mos-ceph': [u'aclamk',
#   u'ifedotov',
#   u'hnarkaytis',
#   u'asheplyakov',
#   u'vsolovei',
#   u'akiselyova',
#   u'rzarzynski',
#   u'mgolub',
#   u'kdanylov'],
#  'mos-cinder': [u'serge-kovaleff', u'ynesenenko', u'aarefiev', u'e0ne'],
#  u'mos-da': [u'isuzdal',
#   u'thomas-goirand',
#   u'mzawadzki-f',
#   u'iyozhikov',
#   u'iudovichenko',
#   u'vsaienko',
#   u'myatsenko',
#   u'mivanov',
#   u'dtrishkin',
#   u'iberezovskiy',
#   u'degorenko',
#   u'skolekonov'],
#  'mos-glance': [u'kkushaev',
#   u'dshakhray',
#   u'ivasilevskaya',
#   u'mfedosin',
#   u'ruhe',
#   u'ativelkov'],
#  'mos-heat': [u'ochuprykov',
#   u'skraynev',
#   u'prazumovsky',
#   u'ruhe',
#   u'pshchelo'],
#  'mos-horizon': [u'serge-kovaleff', u'vokhrimenko', u'pkarikh', u'tsufiev-x'],
#  'mos-ironic': [u'sturivnyi',
#   u'ipukha',
#   u'vsaienko',
#   u'yyekovenko',
#   u'aarefiev',
#   u'kromanenko',
#   u'ashestakov',
#   u'serge-kovaleff',
#   u'svasheka',
#   u'myatsenko',
#   u'vdrok',
#   u'yzveryanskyy',
#   u'pshchelo'],
#  'mos-kernel-networking': [u'fuel-drivers', u'alexander-duyck', u'smatov'],
#  'mos-kernel-storage': [u'fuel-drivers', u'ifedotov', u'hnarkaytis'],
#  'mos-kernel-virt': [u'fuel-drivers', u'pboldin'],
#  'mos-keystone': [u'serge-kovaleff', u'bbobrov', u'amakarov'],
#  'mos-linux': [u'isuzdal',
#   u'amogylchenko',
#   u'teselkin-d',
#   u'asyriy',
#   u'msemenov'],
#  'mos-lma-toolchain': [u'guillaume-thouvenin',
#   u'swann-w',
#   u'simon-pasquier',
#   u'patrick-michel-petit'],
#  'mos-maintenance': [u'srizvan',
#   u'dpuchkin',
#   u'dmeltsaykin',
#   u'akhivin',
#   u'anevenchannyy',
#   u'vsedelnik',
#   u'aermolov'],
#  'mos-murano': [u'ddovbii',
#   u'tlashchova',
#   u'starodubcevna',
#   u'smelikyan',
#   u'ativelkov',
#   u'kzaitsev',
#   u'efedorova',
#   u'slagun',
#   u'ruhe'],
#  'mos-neutron': [u'sbelous',
#   u'scollins',
#   u'kevinbenton',
#   u'alashai8',
#   u'shakhat',
#   u'skolekonov',
#   u'eezhova',
#   u'akamyshnikova',
#   u'aepifanov',
#   u'enikanorov',
#   u'obondarev',
#   u'aignatov'],
#  'mos-nova': [u'mhorban',
#   u'tdurakov',
#   u'pkholkin',
#   u'snikitin',
#   u'andreykurilin',
#   u'rpodolyaka'],
#  'mos-oslo': [u'dukhlov',
#   u'dmitrymex',
#   u'serge-kovaleff',
#   u'ozamiatin',
#   u'dims-v'],
#  'mos-packaging': [u'skolekonov',
#   u'thomas-goirand',
#   u'iudovichenko',
#   u'mzawadzki-f',
#   u'iyozhikov',
#   u'mivanov',
#   u'dtrishkin'],
#  'mos-puppet': [u'mzawadzki-f',
#   u'velovec',
#   u'skolekonov',
#   u'myatsenko',
#   u'vsaienko',
#   u'degorenko',
#   u'iberezovskiy'],
#  'mos-qa': [u'apetrov-n',
#   u'gluk12189',
#   u'yyekovenko',
#   u'sturivnyi',
#   u'ababich',
#   u'tnurlygayanov',
#   u'agalkin',
#   u'svasheka',
#   u'kkuznetsova',
#   u'vgusev',
#   u'vryzhenkin',
#   u'esikachev',
#   u'obutenko',
#   u'kromanenko',
#   u'ogubanov',
#   u'akuznetsova',
#   u'vrovachev',
#   u'ylobankov'],
#  'mos-sahara': [u'esikachev',
#   u'apavlov-n',
#   u'vgridnev',
#   u'nkonovalov',
#   u'sreshetniak',
#   u'slukjanov',
#   u'ruhe'],
#  'mos-scale': [u'dbelova', u'listomin', u'sgalkin'],
#  'mos-security': [u'kkushaev',
#   u'mirantisbot',
#   u'tnurlygayanov',
#   u'aheczko-mirantis',
#   u'mzawadzki-f',
#   u'ebogdanov',
#   u'smelikyan',
#   u'maximov',
#   u'dborodaenko',
#   u'teran',
#   u'mfedosin',
#   u'vsedelnik',
#   u'tzn',
#   u'eshumakher',
#   u'ielterman',
#   u'ralekseenkov',
#   u'asheplyakov',
#   u'amogylchenko',
#   u'amakarov',
#   u'vkuklin',
#   u'pchekin',
#   u'msemenov',
#   u'tsufiev-x',
#   u'e0ne',
#   u'ativelkov',
#   u'dbelova',
#   u'skraynev',
#   u'dmitrymex',
#   u'rpodolyaka',
#   u'r0mikiam',
#   u'aignatov',
#   u'mihgen',
#   u'ruhe',
#   u'imarnat',
#   u'afedorova'],
#  'mos-swift': [u'akhivin']}
